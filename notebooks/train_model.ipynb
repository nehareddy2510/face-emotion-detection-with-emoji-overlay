# %%
import cv2
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
img=cv2.imread('images/jenna_ortega/1.jpg')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
from mtcnn.mtcnn import MTCNN

detector = MTCNN()
results = detector.detect_faces(img)

# %%
results
# Out:
# [{'box': [450, 397, 432, 584],
#   'confidence': np.float64(0.9999008178710938),
#   'keypoints': {'nose': [np.int64(728), np.int64(732)],
#    'mouth_right': [np.int64(780), np.int64(844)],
#    'right_eye': [np.int64(803), np.int64(623)],
#    'left_eye': [np.int64(587), np.int64(616)],
#    'mouth_left': [np.int64(620), np.int64(842)]}}]

# %%
x,y,w,h=results[0]['box']

# %%
img=cv2.rectangle(img,(x,y),(x+h,y+w),(255,0,0),5)
plt.imshow(img)

# %%
face = img[y:y+h, x:x+w]
face = cv2.resize(face, (160,160))
plt.imshow(face)

# %%
class preprcoessing:  
   def __init(self,directory):
       self.directory=directory
       self.targetsize=(160,160)
       self.X=[]
       self.Y=[]
       self.detector=MTCNN()
